# %% [markdown]
# ## Imports & configuration

# %%
import pandas as pd

# %% [markdown]
# ## Medical domain

# %%
results_medical = pd.DataFrame([
    {
        "Model": "LSTM (Word2Vec)",
        "Precision": 0.8475,
        "Recall": 1.0000,
        "F1-score": 0.9174,
        "Accuracy": 0.8475
    },
    {
        "Model": "CNN (FastText)",
        "Precision": 0.8587,
        "Recall": 0.9945,
        "F1-score": 0.9217,
        "Accuracy": 0.8567
    },
    {
        "Model": "CamemBERT",
        "Precision": 0.8910,
        "Recall": 0.9800,
        "F1-score": 0.9424,
        "Accuracy": 0.8910
    }
])

results_medical
# Out:
#              Model  Precision  Recall  F1-score  Accuracy
# 0  LSTM (Word2Vec)     0.8475  1.0000    0.9174    0.8475
# 1   CNN (FastText)     0.8587  0.9945    0.9217    0.8567
# 2        CamemBERT     0.8910  0.9800    0.9424    0.8910

# %% [markdown]
# ## Press domain

# %%
results_press = pd.DataFrame([
    {
        "Model": "LSTM (Word2Vec)",
        "Precision": 0.8755,
        "Recall": 0.8873,
        "F1-score": 0.8814,
        "Accuracy": 0.8251
    },
    {
        "Model": "CNN (FastText)",
        "Precision": 0.8637,
        "Recall": 0.8888,
        "F1-score": 0.8761,
        "Accuracy": 0.8159
    },
    {
        "Model": "CamemBERT",
        "Precision": 0.8871,
        "Recall": 0.9679,
        "F1-score": 0.9258,
        "Accuracy": 0.9160
    }
])

results_press
# Out:
#              Model  Precision  Recall  F1-score  Accuracy
# 0  LSTM (Word2Vec)     0.8755  0.8873    0.8814    0.8251
# 1   CNN (FastText)     0.8637  0.8888    0.8761    0.8159
# 2        CamemBERT     0.8871  0.9679    0.9258    0.9160

# %%
results_medical["Domain"] = "Medical"
results_press["Domain"] = "Press"

results_all = pd.concat([results_medical, results_press], ignore_index=True)
results_all
# Out:
#              Model  Precision  Recall  F1-score  Accuracy   Domain
# 0  LSTM (Word2Vec)     0.8475  1.0000    0.9174    0.8475  Medical
# 1   CNN (FastText)     0.8587  0.9945    0.9217    0.8567  Medical
# 2        CamemBERT     0.8910  0.9800    0.9424    0.8910  Medical
# 3  LSTM (Word2Vec)     0.8755  0.8873    0.8814    0.8251    Press
# 4   CNN (FastText)     0.8637  0.8888    0.8761    0.8159    Press
# 5        CamemBERT     0.8871  0.9679    0.9258    0.9160    Press
